# %%
# from openai import OpenAI
import openai
import textwrap as tw
import textwrap
import re
openai.api_key = "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"

# import secrets_key

# client = OpenAI(api_key=secrets_key.SECRET_KEY)

# %%
def print_result_wrapped(result):
  wrapped_result = tw.wrap(result)
  print("\n".join(wrapped_result))

# %%
# tickets1 = [
#     {
        # "TIC": 383,
        # "title": "Compile List of All Software Licenses",
        # "description": "Compile a list of all softwares used by SF and" + 
        #     "their licenses, including usage start dates, license duration," + 
        #     "and etc. available info.*Task Steps:** Identify all softwares, " +
        #     "tools, platforms, and devices used by SF. Compile all available " + 
        #     "license info on everything identified",
        # "priority": "High",
        # "original_estimate": "54000",
        # "name": "John"
#     }]

# tickets2 = [
#     {
#         "TIC": 381,
#         "title": "Refactor Documentation into Several Pages",
#         "description": "",
#         "priority": "Medium",
#         "original_estimate": "14400",
#         "name": "John"
#     }]

# tickets3 = [
#     {
#         "TIC": 380,
#         "title": "Fix Get PDF Report Toolbox Destroying Airport Full Image",
#         "description": "The 'Get PDF Report' tool fails to include the " +
#         "actual full airport screenshot image in the output report when " +
#         "ran.",
#         "priority": "Critical",
#         "original_estimate": "129600",
#         "name": ""
#     }]

# tickets4 = [
#     {
#         "TIC": 320,
#         "title": "Create live training log text file to visualize training progress",
#         "description": "",
#         "priority": "",
#         "original_estimate": "",
#         "name": "Derick"
#     }]

# tickets5 = [
#     {
#         "TIC": 318,
#         "title": "Improve Input parameter flags",
#         "description": "Remove unnecessary parameters and adding new essential parameters",
#         "priority": "Critical",
#         "original_estimate": "54000",
#         "name": "Derick"
#     }]


# tickets = tickets1 + tickets2 + tickets3 + tickets4 + tickets5

# %%
# tickets1 = [
#     {
#         "TIC": 402,
#         "title": "Fix Incorrect Labeling in Prediction Output",
#         "description": "The prediction script inconsistently labels objects within the model’s output file, with several high-confidence predictions marked as 'unidentified.' This issue appears sporadically but impacts the accuracy of output reports. Steps to resolve: 1) Review model thresholds and update confidence level requirements for labeling. 2) Test the label mapping to confirm each predicted class aligns correctly with expected values. 3) Run a sample batch of predictions to confirm the fix, ensuring 'unidentified' labels are applied only when confidence is below threshold.",
#         "priority": "High",
#         "original_estimate": "72000",
#         "name": "Arielle"
#     }]

# tickets2 = [
#     {
#         "TIC": 404,
#         "title": "Fix Incorrect Date Formatting in Exported CSV",
#         "description": "Exported CSV files from the data extraction script currently display dates in MM/DD/YYYY format, which is inconsistent with the ISO 8601 standard (YYYY-MM-DD) required by clients for compatibility. Steps to address: 1) Update date formatting within the export function to use the correct standard format. 2) Test on sample data exports to confirm dates are correctly formatted. 3) Update documentation and user guidance to reflect the new format in all export instructions.",
#         "priority": "Low",
#         "original_estimate": "14400",
#         "name": "Ruth"
#     }]

# tickets3 = [
#     {
#         "TIC": 410,
#         "title": "Resolve Slow Performance in Data Export Function",
#         "description": "The data export function is taking significantly longer than expected for large datasets, with an average export time exceeding 10 minutes. This impacts productivity and client satisfaction. Proposed fix: 1) Optimize the data retrieval process, possibly by indexing frequently accessed fields or caching data. 2) Review data writing procedures to minimize I/O operations and streamline export formatting. 3) Test with various dataset sizes to confirm improved export times post-optimization.",
#         "priority": "Medium",
#         "original_estimate": "54000",
#         "name": "Chelsey"
#     }]

# tickets4 = [
#     {
#         "TIC": 413,
#         "title": "Set Up Automated Testing Pipeline for CI/CD",
#         "description": "Implement an automated testing pipeline that runs tests for each new commit in the main repository, ensuring code quality and functionality. The pipeline should: 1) trigger upon pull requests, 2) run unit and integration tests, 3) generate a report on test results, and 4) block any merge with failing tests. Confirm the pipeline works on all major branches.",
#         "priority": "Critical",
#         "original_estimate": "108000",
#         "name": "Pushyami"
#     }]

# tickets5 = [
#     {
#         "TIC": 416,
#         "title": "Implement Automated Notification System for Task Completion",
#         "description": "Develop a notification system that alerts team members upon task completion within the automation scripts. The system should: 1) integrate with existing task scripts, 2) send notifications via email or Slack, and 3) include task details, completion time, and any errors encountered. Test notifications for various task types to ensure accurate reporting.",
#         "priority": "Medium",
#         "original_estimate": "54000",
#         "name": "Arielle"
#     }]

# tickets = tickets1 + tickets2 + tickets3 + tickets4 + tickets5

# %%
tickets1 = [
    {
        "TIC": 402,
        "title": "", # Empty title
        "description": "The prediction script inconsistently labels objects within the model’s output file, with several high-confidence predictions marked as 'unidentified.' This issue appears sporadically but impacts the accuracy of output reports. Steps to resolve: 1) Review model thresholds and update confidence level requirements for labeling. 2) Test the label mapping to confirm each predicted class aligns correctly with expected values.",
        "priority": "High",
        "original_estimate": "",  # Empty estimate
        "name": "John"
    }]

tickets2 = [
    {
        "TIC": 404,
        "title": "",    # Empty title
        "description": "",  # Empty description
        "priority": "Low",
        "original_estimate": "14400",
        "name": "Derick"  
    }]

tickets3 = [
    {
        "TIC": 410,
        "title": "Resolve Performance Issue with Data Export",
        "description": "The data export function takes longer than expected for large datasets. Optimize the data retrieval and formatting processes. Consider introducing a background task to handle exports, allowing users to continue working while exports complete.",
        "priority": "Medium",
        "original_estimate": "72000",  # Adjusted estimate
        "name": "Derick"
    }]

tickets4 = [
    {
        "TIC": 413,
        "title": "Automate CI/CD Testing Pipeline Setup",
        "description": "Create a CI/CD testing pipeline to automatically validate code quality. The pipeline should include unit tests, integration tests, and generate a detailed report. Additionally, configure a notification system to alert team members if a test fails.",
        "priority": "Critical",
        "original_estimate": "108000",
        "name": "Derick"
    }]

tickets5 = [
    {
        "TIC": 383,
        "title": "Compile List of All Software Licenses",
        "description": "Compile a list of all softwares used by the company and" + 
            "their licenses, including usage start dates, license duration," + 
            "and etc. available info.*Task Steps:** Identify all softwares, " +
            "tools, platforms, and devices used by SF. Compile all available " + 
            "license info on everything identified",
        "priority": "High",
        "original_estimate": "54000",
        "name": "John"
    }]

tickets = tickets1 + tickets2 + tickets3 + tickets4 + tickets5

# %%
test = tickets5[0]
print(test)
# Out:
# {'TIC': 383, 'title': 'Compile List of All Software Licenses', 'description': 'Compile a list of all softwares used by SF andtheir licenses, including usage start dates, license duration,and etc. available info.*Task Steps:** Identify all softwares, tools, platforms, and devices used by SF. Compile all available license info on everything identified', 'priority': 'High', 'original_estimate': '54000', 'name': 'John'}

# %%
#Summarize Ticket

# prompt_for_summary = f"Generate a summary of this ticket. Title:{test['title']}, Description:{test['description']}."
# response_summary = openai.chat.completions.create(
#         model="gpt-4o-mini",
#         max_tokens=256, 
#         messages=[{"role": "user", "content": prompt_for_summary}])
# output_summary = response_summary.choices[0].message.content  
# paragraphs = output_summary.split('\n')
# wrapped_paragraphs = [textwrap.fill(paragraph, width=100) for paragraph in paragraphs]
# wrapped_summary = '\n'.join(wrapped_paragraphs)
# print(f"Ticket: {test['TIC']} \nSummary:\n{wrapped_summary}\n")

# %%
#Ask for Suggestions to Complete ticket

prompt_for_suggestion = (f"Provide suggestions on how I can complete this ticket. Title:{test['title']}, " + 
                         f"Description:{test['description']}. Provide code snippet if necessary and/or " + 
                         f"links to relevant documentation based on the content of the ticket. Do not provide code snippet if ticket does not need it.")
response_suggestion = openai.chat.completions.create(
        model="gpt-4o-mini",
        max_tokens=2000, 
        messages=[{"role": "user", "content": prompt_for_suggestion}])
output_suggestion = response_suggestion.choices[0].message.content  
paragraphs_sugg = output_suggestion.split('\n')
wrapped_paragraphs_sugg = [textwrap.fill(paragraph_sugg, width=100) for paragraph_sugg in paragraphs_sugg]
wrapped_suggestion = '\n'.join(wrapped_paragraphs_sugg)
print(f"Suggestions for Ticket {test['TIC']}:\n{wrapped_suggestion}\n")
# Out:
# Suggestions for Ticket 383:
# To complete the ticket titled "Compile List of All Software Licenses," you can follow these
# structured steps:
#
# ### Task Steps
#
# 1. **Identify All Software, Tools, Platforms, and Devices**
#    - Conduct a comprehensive audit of the existing software and tools used by your organization
# (SF).
#    - Common sources for identification include:
#      - IT inventory systems
#      - Procurement records
#      - Software installation logs
#      - Surveys or questionnaires to teams
#      - Discussions with IT staff and department heads
#
# 2. **Gather License Information**
#    - Once you've identified the software, gather all relevant licensing information, which typically
# includes:
#      - Software name
#      - Version
#      - Usage start date
#      - License type (e.g., perpetual, subscription, open-source)
#      - License duration (i.e., expiration dates or renewal terms)
#      - Vendor contact information
# ...

# %%
tickets_info = "\n".join(
    f"TIC: {ticket['TIC']}, Title: {ticket['title']}, Description: {ticket['description']}"
    for ticket in tickets)

prompt_for_recommend = (f"Which ticket should I work on next based on task type and how fast I " + 
                        f"can get it done. Here are the tickets to choose from:{tickets_info}.")
response_recommend = openai.chat.completions.create(
        model="gpt-4o-mini",
        max_tokens=2000, 
        messages=[{"role": "user", "content": prompt_for_recommend}])
output_recommend = response_recommend.choices[0].message.content  
paragraphs_rec = output_recommend.split('\n')
wrapped_paragraphs_rec = [textwrap.fill(paragraph_rec, width=100) for paragraph_rec in paragraphs_rec]
wrapped_recommend = '\n'.join(wrapped_paragraphs_rec)
# print(f"I recommend you work on ticket {ticket['TIC']}. Here's information on this ticket.\n\n{wrapped_recommend}\n")
print("Recommended Ticket:\n")
print(wrapped_recommend)
# Out:
# Recommended Ticket:
#
# To decide which ticket to work on next, let's analyze the tasks based on their descriptions and
# potential time to complete:
#
# 1. **TIC 402**: Fixing an inconsistency in the prediction script could be complex, depending on how
# deeply you need to dive into the model's functioning. It involves reviewing and updating thresholds
# and testing mappings, which could take a significant amount of time.
#
# 2. **TIC 404**: No description is available, so you would need to assess the task once more
# information is provided.
#
# 3. **TIC 410**: Resolving the performance issue with data exports likely requires an understanding
# of the current data retrieval processes and possibly significant changes to optimize it. Depending
# on the dataset size and the complexity of the current export function, this could take considerable
# time.
#
# 4. **TIC 413**: Automating the CI/CD pipeline might involve setting up tools or frameworks, but if
# ...

# %%
#Recommend next ticket for user
# def recommend_ticket(tickets):
#     priority_map = {'Critical': 0, 'High': 1, 'Medium': 2, 'Low': 3}
#     tickets.sort(key=lambda x: (
#         priority_map.get(x['priority'], float('inf')),  
#         int(x['original_estimate']) if x['original_estimate'].isdigit() else float('inf')  
#     ))
#     return tickets[0]  

# recommended_ticket = recommend_ticket(tickets)
# prompt_for_recommendation = (f"Summarize in a paragraph this ticket information: Title: {recommended_ticket['title']}, " +
#     f"Description: {recommended_ticket['description']}, Priority: {recommended_ticket['priority']}, Original Estimate: {recommended_ticket['original_estimate']}, Name: {recommended_ticket['name']}")
# # prompt_for_recommendation = (f"Summarize in a paragraph this ticket information: Title: {recommended_ticket['title']}, " +
#     # f"Description: {recommended_ticket['description']}, Priority: {recommended_ticket['priority']}, Original Estimate: {recommended_ticket['original_estimate']}, Name: {recommended_ticket['name']}")
# response_recommend = openai.chat.completions.create(
#     model="gpt-4o-mini",
#     max_tokens=256, 
#     messages=[{"role": "user", "content": prompt_for_recommendation}])
# output_recommend = response_recommend.choices[0].message.content 
# paragraphs_rec = output_recommend.split('\n')
# wrapped_paragraphs_rec = [textwrap.fill(paragraph_rec, width=100) for paragraph_rec in paragraphs_rec]
# wrapped_recommend = '\n'.join(wrapped_paragraphs_rec)
# print(f"I recommend you work on ticket {recommended_ticket['TIC']}. Here's information on this ticket.\n\n{wrapped_recommend}\n")
# Out:
# I recommend you work on ticket 318. Here's information on this ticket.
#
# The ticket titled "Improve Input Parameter Flags," assigned to Derick, aims to enhance the current
# input parameter system by removing unnecessary parameters and introducing new essential ones. This
# ticket has been marked with a critical priority status, indicating its importance for immediate
# attention. The original time estimate to complete this task is 54,000 hours.
